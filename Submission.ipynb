# %%
import pandas as pd
import numpy as np
import collections
import datetime as dt
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Functions on bureau dataset

# %%
def max_comp(list_values):
    ctr = collections.Counter(list_values)
    return max(ctr, key=ctr.get)

def if_one(list_values):
    if 1 in list_values:
        return 1
    else:
        return 0
    
def is_loan(list_values):
    loan = []
    for i in list_values:
        if 'Loan' in i:
            loan.append(i)
    return loan

def one_hot(df,variable,top_x_labels):
    for label in top_x_labels:
        df[variable+"_"+label] = np.where(data[variable]== label,1,0)
    df.drop([variable], axis=1, inplace=True)

# %%
def prerequisites_for_one_hot_bureau(data):
    # returns the list of some columns
    all_loans = is_loan(data["ACCT-TYPE"].value_counts().index)
    all_contributors = data["CONTRIBUTOR-TYPE"].value_counts().index
    top_3_account_status = data["ACCOUNT-STATUS"].value_counts().sort_values(ascending = False).head(3).index
    top_3_asset_classes = data["ASSET_CLASS"].value_counts().sort_values(ascending = False).head(3).index
    top_3_ownerships = data["OWNERSHIP-IND"].value_counts().sort_values(ascending = False).head(3).index
    return all_loans, all_contributors, top_3_account_status, top_3_asset_classes, top_3_ownerships

# %%
def preprocessing_bureau(data, all_loans, all_contributors, top_3_account_status, top_3_asset_classes, top_3_ownerships):
    # final preprocessing on bureau data
    data["SELF-INDICATOR"] = pd.get_dummies(data["SELF-INDICATOR"],drop_first= True)
    data["MATCH-TYPE"] = pd.get_dummies(data["MATCH-TYPE"], drop_first=True)
    one_hot(data,"ACCT-TYPE", all_loans)
    one_hot(data,"CONTRIBUTOR-TYPE",all_contributors)
    one_hot(data,"ACCOUNT-STATUS",top_3_account_status)
    one_hot(data,"OWNERSHIP-IND", top_3_ownerships)
    data['CREDIT-LIMIT/SANC AMT'] = data['CREDIT-LIMIT/SANC AMT'].str.replace(",","").fillna(0).astype('int')
    data['DISBURSED-AMT/HIGH CREDIT'] = data['DISBURSED-AMT/HIGH CREDIT'].str.replace(",","").fillna(0).astype('int')
    data["INSTALLMENT-AMT"] = data['INSTALLMENT-AMT'].str.split("/").str[0]
    data['INSTALLMENT-AMT'] = data['INSTALLMENT-AMT'].str.replace(",","").fillna(0).astype('int')
    data["CURRENT-BAL"] = data["CURRENT-BAL"].str.replace(',',"").fillna(0).astype('int')
    data["OVERDUE-AMT"]=data['OVERDUE-AMT'].str.replace(",","").fillna(0).astype('int')
    data["WRITE-OFF-AMT"]=data["WRITE-OFF-AMT"].fillna(0).astype('int')
    one_hot(data,"ASSET_CLASS",top_3_asset_classes)
    output = data.groupby(["ID"]).agg(
        TENURE = ("TENURE", sum),
        DISBURSED_AMT_HIGH_CREDIT = ("DISBURSED-AMT/HIGH CREDIT", sum),
        SELF_INICATOR = ("SELF-INDICATOR", np.mean),
        MATCH_TYPE = ("MATCH-TYPE", np.mean),
        DATE_REPORTED = ("DATE-REPORTED", max),
        DISBURSED_DT = ("DISBURSED-DT", max),
        LAST_PAYMENT_DATE = ("LAST-PAYMENT-DATE", max),
        CREDIT_LIMIT_SANC_AMT = ("CREDIT-LIMIT/SANC AMT", sum),
        INSTALLMENT_AMT = ("INSTALLMENT-AMT", sum),
        CURRENT_BAL = ("CURRENT-BAL", max),
        OVERDUE_AMT = ("OVERDUE-AMT", max),
        WRITE_OFF_AMT = ("WRITE-OFF-AMT", sum),
        OWNERSHIP_IND_Individual = ("OWNERSHIP-IND_Individual", lambda x: 1 if sum(x) > 0 else 0),
        OWNERSHIP_IND_Joint = ("OWNERSHIP-IND_Joint", lambda x: 1 if sum(x) > 0 else 0),
        OWNERSHIP_IND_Guarantor = ("OWNERSHIP-IND_Guarantor", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Tractor_Loan = ("ACCT-TYPE_Tractor Loan", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Gold_Loan = ("ACCT-TYPE_Gold Loan", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Business_Loan_Priority_Sector_Agriculture = ("ACCT-TYPE_Business Loan Priority Sector  Agriculture", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Auto_Loan_Personal = ("ACCT-TYPE_Auto Loan (Personal)", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Commercial_Vehicle_Loan = ("ACCT-TYPE_Commercial Vehicle Loan", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Two_Wheeler_Loan = ("ACCT-TYPE_Two-Wheeler Loan", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Consumer_Loan = ("ACCT-TYPE_Consumer Loan", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Personal_Loan = ("ACCT-TYPE_Personal Loan", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Housing_Loan = ("ACCT-TYPE_Housing Loan", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Construction_Equipment_Loan = ("ACCT-TYPE_Construction Equipment Loan", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Business_Loan_General = ("ACCT-TYPE_Business Loan General", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Loan_Against_Bank_Deposits = ("ACCT-TYPE_Loan Against Bank Deposits", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Used_Car_Loan = ("ACCT-TYPE_Used Car Loan", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Business_Loan_Priority_Sector_Small_Business = ("ACCT-TYPE_Business Loan Priority Sector  Small Business", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Loan_Against_Shares_Securities = ("ACCT-TYPE_Loan Against Shares / Securities", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Property_Loan = ("ACCT-TYPE_Property Loan", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Business_Loan_Priority_Sector_Others = ("ACCT-TYPE_Business Loan Priority Sector  Others", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Mudra_Loans = ("ACCT-TYPE_Mudra Loans   Shishu / Kishor / Tarun", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Education_Loan = ("ACCT-TYPE_Education Loan", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Business_Loan_Secured  = ("ACCT-TYPE_Business Loan - Secured", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Business_Loan_Against_Bank_Deposits = ("ACCT-TYPE_Business Loan Against Bank Deposits", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Business_Loan_Unsecured = ("ACCT-TYPE_Business Loan Unsecured", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Microfinance_Business_Loan = ("ACCT-TYPE_Microfinance Business Loan", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Loan_to_Professional = ("ACCT-TYPE_Loan to Professional", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Microfinance_Personal_Loan = ("ACCT-TYPE_Microfinance Personal Loan", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Microfinance_Housing_Loan = ("ACCT-TYPE_Microfinance Housing Loan", lambda x: 1 if sum(x) > 0 else 0),
        ACCT_TYPE_Commercial_Equipment_Loan = ("ACCT-TYPE_Commercial Equipment Loan", lambda x: 1 if sum(x) > 0 else 0),
        #ACCT_TYPE_Loan_on_Credit_Card  = ("ACCT-TYPE_Loan on Credit Card", lambda x: 1 if sum(x) > 0 else 0),
        CONTRIBUTOR_TYPE_NBF = ("CONTRIBUTOR-TYPE_NBF", lambda x: 1 if sum(x) > 0 else 0),
        CONTRIBUTOR_TYPE_NAB = ("CONTRIBUTOR-TYPE_NAB", lambda x: 1 if sum(x) > 0 else 0),
        CONTRIBUTOR_TYPE_PRB = ("CONTRIBUTOR-TYPE_PRB", lambda x: 1 if sum(x) > 0 else 0),
        CONTRIBUTOR_TYPE_RRB = ("CONTRIBUTOR-TYPE_RRB", lambda x: 1 if sum(x) > 0 else 0),
        CONTRIBUTOR_TYPE_COP = ("CONTRIBUTOR-TYPE_COP", lambda x: 1 if sum(x) > 0 else 0),
        CONTRIBUTOR_TYPE_MFI = ("CONTRIBUTOR-TYPE_MFI", lambda x: 1 if sum(x) > 0 else 0),
        CONTRIBUTOR_TYPE_HFC = ("CONTRIBUTOR-TYPE_HFC", lambda x: 1 if sum(x) > 0 else 0),
        CONTRIBUTOR_TYPE_CCC = ("CONTRIBUTOR-TYPE_CCC", lambda x: 1 if sum(x) > 0 else 0),
        CONTRIBUTOR_TYPE_FRB = ("CONTRIBUTOR-TYPE_FRB", lambda x: 1 if sum(x) > 0 else 0),
        CONTRIBUTOR_TYPE_SFB = ("CONTRIBUTOR-TYPE_SFB", lambda x: 1 if sum(x) > 0 else 0),
        #CONTRIBUTOR_TYPE_ARC = ("CONTRIBUTOR-TYPE_ARC", lambda x: 1 if sum(x) > 0 else 0),
        CONTRIBUTOR_TYPE_OFI = ("CONTRIBUTOR-TYPE_OFI", lambda x: 1 if sum(x) > 0 else 0),
        ACCOUNT_STATUS_Closed = ("ACCOUNT-STATUS_Closed", lambda x: 1 if sum(x) > 0 else 0),
        ACCOUNT_STATUS_Active = ("ACCOUNT-STATUS_Active", lambda x: 1 if sum(x) > 0 else 0),
        ACCOUNT_STATUS_Delinquent = ("ACCOUNT-STATUS_Delinquent", lambda x: 1 if sum(x) > 0 else 0),
        ASSET_CLASS_Doubtful = ("ASSET_CLASS_Doubtful", lambda x: 1 if sum(x) > 0 else 0),
        ASSET_CLASS_Standard = ("ASSET_CLASS_Standard", lambda x: 1 if sum(x) > 0 else 0),
        ASSET_CLASS_SubStandard = ("ASSET_CLASS_SubStandard", lambda x: 1 if sum(x) > 0 else 0),
    )
    return output

# %% [markdown]
# ### Functions on the first dataset

# %%
def prerequisites_for_one_hot_dataset(data):
    # returns the list of some columns
    top_3_frequencies = data["Frequency"].value_counts().sort_values(ascending = False).head(3).index
    data["SEX"] = data["SEX"].fillna("Others")
    top_2_genders = data["SEX"].value_counts().sort_values(ascending = False).head(2).index
    top_14_states = data["State"].value_counts().sort_values(ascending = False).head(14).index
    top_4_payments = data["PaymentMode"].value_counts().sort_values(ascending = False).head(4).index
    return top_3_frequencies, top_2_genders, top_14_states, top_4_payments

# %%
def one_hot_for_dataset(data, top_3_frequencies, top_2_genders, top_14_states, top_4_payments):
    one_hot(data,"Frequency",top_3_frequencies)
    one_hot(data,"SEX",top_2_genders)
    one_hot(data,"State",top_14_states)
    one_hot(data,"PaymentMode",top_4_payments)
    return data

# %% [markdown]
# ### Filling null values

# %%
def create_encoders(data):
    installment_encoder = LabelEncoder()
    loan_status_encoder = LabelEncoder()
    age_imputer = SimpleImputer(strategy= "median")
    tenure_imputer = SimpleImputer(strategy= "median")
    income_imputer = SimpleImputer()
    age_imputer.fit(np.array(data['AGE']).reshape(-1,1))
    tenure_imputer.fit(np.array(data['TENURE']).reshape(-1,1))
    income_imputer.fit(np.array(data['MonthlyIncome']).reshape(-1,1))
    installment_encoder.fit(data["InstlmentMode"])
    loan_status_encoder.fit(data["LoanStatus"])
    return age_imputer, tenure_imputer, income_imputer, installment_encoder, loan_status_encoder

# %%
def fill_na(data, age_imputer, tenure_imputer, income_imputer, installment_encoder, loan_status_encoder):
    
    # filling null dates
    current_date = dt.datetime.now()
    current_time = current_date.strftime('%Y-%m-%d')
    data["DATE_REPORTED_YEAR"] = pd.to_datetime(data['DATE_REPORTED'], errors='coerce').dt.year
    data["DATE_REPORTED_MONTH"] = pd.to_datetime(data['DATE_REPORTED'], errors='coerce').dt.month
    data["DisbursalDateMonth"] = pd.to_datetime(data['DisbursalDate'], errors='coerce').dt.month
    data["DisbursalDateYear"] = pd.to_datetime(data['DisbursalDate'], errors='coerce').dt.year
    data["DISBURSED_DT_YEAR"] = pd.to_datetime(data['DISBURSED_DT'], errors='coerce').dt.year
    data["DISBURSED_DT_MONTH"] = pd.to_datetime(data['DISBURSED_DT'], errors='coerce').dt.month
    data['MaturityMonth'] = pd.to_datetime(data['MaturityDAte'], errors='coerce').dt.month
    data['MaturityYear'] = pd.to_datetime(data['MaturityDAte'], errors='coerce').dt.year
    data['AuthDateMonth'] = pd.to_datetime(data['AuthDate'], errors='coerce').dt.month
    data['AuthDateYear'] = pd.to_datetime(data['AuthDate'], errors='coerce').dt.year
    data['LAST_PAYMENT_MONTH'] = pd.to_datetime(data['LAST_PAYMENT_DATE'], errors='coerce').dt.month
    data['LAST_PAYMENT_YEAR'] = pd.to_datetime(data['LAST_PAYMENT_DATE'], errors='coerce').dt.year
    
    # filling null zipcodes
    for i,j in data.groupby(["BranchID"]):
        col = max_comp(list(j["ZiPCODE"]))
        a = j.iloc[0]["BranchID"]
        data.loc[(data['ZiPCODE'].isnull() == True) & (data['BranchID'] == a), "ZiPCODE"] = col
    
    # filling using imputers
    data["AGE"] = age_imputer.transform(np.array(data['AGE']).reshape(-1,1))
    data["TENURE"] = tenure_imputer.transform(np.array(data['TENURE']).reshape(-1,1))
    data["MonthlyIncome"] = income_imputer.transform(np.array(data['MonthlyIncome']).reshape(-1,1))
    
    # filling using encoder
    data["InstlmentMode"] = installment_encoder.transform(data["InstlmentMode"])
    data["LoanStatus"] = loan_status_encoder.transform(data["LoanStatus"])
    
    # filling for Manufacturer ID
    col = max_comp(list(data["ManufacturerID"]))
    data["ManufacturerID"] = data["ManufacturerID"].fillna(col)
    return data

# %% [markdown]
# ### Importing bureau data

# %%
input_data_1 = pd.read_excel("Train/train_bureau.xlsx", engine="openpyxl")

# %%
data = input_data_1.copy(deep=True)
all_loans, all_contributors, top_3_account_status, top_3_asset_classes, top_3_ownerships = prerequisites_for_one_hot_bureau(data)
bureau_data = preprocessing_bureau(data, all_loans, all_contributors, top_3_account_status, top_3_asset_classes, top_3_ownerships)

# %%
# Out:
# '2021-02-07 21:43:45.932849'

# %% [markdown]
# ### Importing train data

# %%
input_data_2 = pd.read_excel("Train/train_Data.xlsx", engine='openpyxl')

# %%
data = input_data_2.copy(deep=True)

# %%
top_3_frequencies, top_2_genders, top_14_states, top_4_payments = prerequisites_for_one_hot_dataset(data)
data = one_hot_for_dataset(data, top_3_frequencies, top_2_genders, top_14_states, top_4_payments)

# %% [markdown]
# ### Merging both datasets

# %%
train_data = pd.merge(bureau_data, data, on="ID")
age_imputer, tenure_imputer, income_imputer, installment_encoder, loan_status_encoder = create_encoders(train_data)
train_data = fill_na(train_data, age_imputer, tenure_imputer, income_imputer, installment_encoder, loan_status_encoder)

# %%
train_ID = train_data["ID"]

# %%
y_train = train_data["Top-up Month"]
y_encode = LabelEncoder()
y_train = y_encode.fit_transform(y_train)

# %%
train_data.drop(["City", "Area", "ID", "DisbursalDate","DISBURSED_DT",
                "MaturityDAte", "AuthDate","Top-up Month","DATE_REPORTED","LAST_PAYMENT_DATE"
                ], axis=1, inplace=True)

# %% [markdown]
# ### Working on test data

# %%
input_data_3 = pd.read_excel("Test/test_bureau.xlsx", engine="openpyxl")

# %%
data = input_data_3.copy(deep=True)
bureau_data = preprocessing_bureau(data, all_loans, all_contributors, top_3_account_status, top_3_asset_classes, top_3_ownerships)

# %%
input_data_4 = pd.read_excel("Test/test_Data.xlsx", engine='openpyxl')

# %%
data = input_data_4.copy(deep=True)
data = one_hot_for_dataset(data, top_3_frequencies, top_2_genders, top_14_states, top_4_payments)

# %%
test_data = pd.merge(bureau_data, data, on="ID")
test_data = fill_na(test_data, age_imputer, tenure_imputer, income_imputer, installment_encoder, loan_status_encoder)

# %%
ID = test_data["ID"]
test_data.drop(["City", "Area", "ID", "DisbursalDate","DATE_REPORTED",
                "MaturityDAte", "AuthDate","DISBURSED_DT","LAST_PAYMENT_DATE"
                ], axis=1, inplace=True)

# %% [markdown]
# ### Working on ML models

# %% [markdown]
# #### CatBoost classifier

# %%
import catboost as ctb
from sklearn.model_selection import RandomizedSearchCV

# %%
random_grid = {'learning_rate': [0.5, 0.60, 0.7],
               'depth': [4,5,6],
               'iterations': [650, 700, 750]}


CBC = RandomizedSearchCV(estimator = ctb.CatBoostClassifier(), param_distributions = random_grid, cv = 3, n_jobs=5, verbose = 2)

CBC.fit(train_data, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  30 out of  30 | elapsed: 16.2min finished
# 0:	learn: 0.7112971	total: 58.7ms	remaining: 38.1s
# 1:	learn: 0.6209845	total: 109ms	remaining: 35.3s
# 2:	learn: 0.5752582	total: 159ms	remaining: 34.4s
# 3:	learn: 0.5567135	total: 208ms	remaining: 33.6s
# 4:	learn: 0.5340287	total: 281ms	remaining: 36.2s
# 5:	learn: 0.5216233	total: 327ms	remaining: 35.1s
# 6:	learn: 0.5136661	total: 382ms	remaining: 35.1s
# 7:	learn: 0.5027080	total: 436ms	remaining: 35s
# 8:	learn: 0.4970222	total: 484ms	remaining: 34.5s
# 9:	learn: 0.4880148	total: 545ms	remaining: 34.9s
# 10:	learn: 0.4815030	total: 600ms	remaining: 34.9s
# 11:	learn: 0.4784503	total: 660ms	remaining: 35.1s
# 12:	learn: 0.4755548	total: 718ms	remaining: 35.2s
# 13:	learn: 0.4714715	total: 770ms	remaining: 35s
# 14:	learn: 0.4678819	total: 826ms	remaining: 35s
# 15:	learn: 0.4661326	total: 877ms	remaining: 34.8s
# 16:	learn: 0.4637065	total: 922ms	remaining: 34.3s
# 17:	learn: 0.4619796	total: 974ms	remaining: 34.2s
# 18:	learn: 0.4606344	total: 1.03s	remaining: 34.2s
# 19:	learn: 0.4570758	total: 1.09s	remaining: 34.3s
# 20:	learn: 0.4557461	total: 1.14s	remaining: 34.2s
# 21:	learn: 0.4550779	total: 1.19s	remaining: 34s
# 22:	learn: 0.4536764	total: 1.25s	remaining: 34s
# 23:	learn: 0.4516436	total: 1.29s	remaining: 33.8s
# 24:	learn: 0.4497691	total: 1.35s	remaining: 33.7s
# 25:	learn: 0.4478253	total: 1.4s	remaining: 33.5s
# 26:	learn: 0.4466815	total: 1.45s	remaining: 33.4s
# 27:	learn: 0.4457518	total: 1.5s	remaining: 33.2s
# 28:	learn: 0.4446544	total: 1.54s	remaining: 33s
# 29:	learn: 0.4438277	total: 1.6s	remaining: 33.1s
# 30:	learn: 0.4426830	total: 1.66s	remaining: 33s
# 31:	learn: 0.4421286	total: 1.7s	remaining: 32.9s
# 32:	learn: 0.4404964	total: 1.75s	remaining: 32.8s
# 33:	learn: 0.4399436	total: 1.8s	remaining: 32.6s
# 34:	learn: 0.4393755	total: 1.86s	remaining: 32.7s
# 35:	learn: 0.4383779	total: 1.91s	remaining: 32.6s
# 36:	learn: 0.4380455	total: 1.96s	remaining: 32.5s
# 37:	learn: 0.4368890	total: 2.03s	remaining: 32.7s
# 38:	learn: 0.4361649	total: 2.08s	remaining: 32.6s
# 39:	learn: 0.4357805	total: 2.13s	remaining: 32.4s
# 40:	learn: 0.4353085	total: 2.17s	remaining: 32.2s
# 41:	learn: 0.4340683	total: 2.23s	remaining: 32.3s
# 42:	learn: 0.4335376	total: 2.28s	remaining: 32.1s
# 43:	learn: 0.4331604	total: 2.33s	remaining: 32.1s
# 44:	learn: 0.4324328	total: 2.38s	remaining: 32s
# 45:	learn: 0.4321872	total: 2.43s	remaining: 31.9s
# 46:	learn: 0.4312797	total: 2.48s	remaining: 31.8s
# 47:	learn: 0.4309399	total: 2.52s	remaining: 31.7s
# 48:	learn: 0.4304282	total: 2.58s	remaining: 31.7s
# 49:	learn: 0.4301234	total: 2.63s	remaining: 31.6s
# 50:	learn: 0.4295644	total: 2.68s	remaining: 31.5s
# 51:	learn: 0.4290263	total: 2.72s	remaining: 31.3s
# 52:	learn: 0.4285915	total: 2.77s	remaining: 31.2s
# 53:	learn: 0.4281357	total: 2.83s	remaining: 31.3s
# 54:	learn: 0.4275994	total: 2.88s	remaining: 31.2s
# 55:	learn: 0.4272131	total: 2.94s	remaining: 31.1s
# 56:	learn: 0.4265985	total: 2.99s	remaining: 31.1s
# 57:	learn: 0.4262178	total: 3.04s	remaining: 31s
# 58:	learn: 0.4260416	total: 3.09s	remaining: 31s
# 59:	learn: 0.4252801	total: 3.13s	remaining: 30.8s
# 60:	learn: 0.4249588	total: 3.18s	remaining: 30.7s
# 61:	learn: 0.4233318	total: 3.25s	remaining: 30.8s
# 62:	learn: 0.4230759	total: 3.3s	remaining: 30.8s
# 63:	learn: 0.4228722	total: 3.34s	remaining: 30.6s
# 64:	learn: 0.4225904	total: 3.39s	remaining: 30.5s
# 65:	learn: 0.4222822	total: 3.45s	remaining: 30.5s
# 66:	learn: 0.4218976	total: 3.5s	remaining: 30.5s
# 67:	learn: 0.4214603	total: 3.55s	remaining: 30.4s
# 68:	learn: 0.4211892	total: 3.59s	remaining: 30.3s
# 69:	learn: 0.4209411	total: 3.65s	remaining: 30.2s
# 70:	learn: 0.4207504	total: 3.7s	remaining: 30.1s
# 71:	learn: 0.4205373	total: 3.74s	remaining: 30s
# 72:	learn: 0.4202354	total: 3.79s	remaining: 30s
# 73:	learn: 0.4199898	total: 3.85s	remaining: 30s
# 74:	learn: 0.4198631	total: 3.89s	remaining: 29.8s
# 75:	learn: 0.4195295	total: 3.94s	remaining: 29.8s
# 76:	learn: 0.4191424	total: 3.99s	remaining: 29.7s
# 77:	learn: 0.4190571	total: 4.04s	remaining: 29.6s
# 78:	learn: 0.4188976	total: 4.08s	remaining: 29.5s
# 79:	learn: 0.4186948	total: 4.12s	remaining: 29.3s
# 80:	learn: 0.4180461	total: 4.18s	remaining: 29.4s
# 81:	learn: 0.4178213	total: 4.23s	remaining: 29.3s
# 82:	learn: 0.4177005	total: 4.27s	remaining: 29.2s
# 83:	learn: 0.4174102	total: 4.32s	remaining: 29.1s
# 84:	learn: 0.4166516	total: 4.37s	remaining: 29s
# 85:	learn: 0.4162816	total: 4.43s	remaining: 29.1s
# 86:	learn: 0.4161082	total: 4.48s	remaining: 29s
# 87:	learn: 0.4155955	total: 4.53s	remaining: 28.9s
# 88:	learn: 0.4150883	total: 4.58s	remaining: 28.9s
# 89:	learn: 0.4148071	total: 4.63s	remaining: 28.8s
# 90:	learn: 0.4147097	total: 4.67s	remaining: 28.7s
# 91:	learn: 0.4146448	total: 4.71s	remaining: 28.6s
# 92:	learn: 0.4144323	total: 4.76s	remaining: 28.5s
# 93:	learn: 0.4142049	total: 4.81s	remaining: 28.5s
# 94:	learn: 0.4140926	total: 4.86s	remaining: 28.4s
# 95:	learn: 0.4136791	total: 4.91s	remaining: 28.4s
# 96:	learn: 0.4135672	total: 4.96s	remaining: 28.3s
# 97:	learn: 0.4132208	total: 5.01s	remaining: 28.2s
# 98:	learn: 0.4129763	total: 5.05s	remaining: 28.1s
# 99:	learn: 0.4127832	total: 5.09s	remaining: 28s
# 100:	learn: 0.4124969	total: 5.14s	remaining: 28s
# 101:	learn: 0.4122857	total: 5.19s	remaining: 27.9s
# 102:	learn: 0.4121531	total: 5.24s	remaining: 27.8s
# 103:	learn: 0.4119231	total: 5.28s	remaining: 27.7s
# 104:	learn: 0.4117874	total: 5.32s	remaining: 27.6s
# 105:	learn: 0.4115917	total: 5.37s	remaining: 27.6s
# 106:	learn: 0.4110826	total: 5.44s	remaining: 27.6s
# 107:	learn: 0.4109334	total: 5.48s	remaining: 27.5s
# 108:	learn: 0.4105399	total: 5.53s	remaining: 27.4s
# 109:	learn: 0.4102633	total: 5.57s	remaining: 27.3s
# 110:	learn: 0.4101298	total: 5.63s	remaining: 27.3s
# 111:	learn: 0.4096457	total: 5.68s	remaining: 27.3s
# 112:	learn: 0.4094143	total: 5.73s	remaining: 27.2s
# 113:	learn: 0.4091792	total: 5.77s	remaining: 27.1s
# 114:	learn: 0.4090593	total: 5.83s	remaining: 27.1s
# 115:	learn: 0.4089165	total: 5.88s	remaining: 27.1s
# 116:	learn: 0.4086540	total: 5.92s	remaining: 27s
# 117:	learn: 0.4084633	total: 5.97s	remaining: 26.9s
# 118:	learn: 0.4073342	total: 6.03s	remaining: 26.9s
# 119:	learn: 0.4068695	total: 6.08s	remaining: 26.8s
# 120:	learn: 0.4067044	total: 6.12s	remaining: 26.7s
# 121:	learn: 0.4066302	total: 6.16s	remaining: 26.7s
# 122:	learn: 0.4064673	total: 6.2s	remaining: 26.6s
# 123:	learn: 0.4061655	total: 6.25s	remaining: 26.5s
# 124:	learn: 0.4060528	total: 6.29s	remaining: 26.4s
# 125:	learn: 0.4059494	total: 6.34s	remaining: 26.4s
# 126:	learn: 0.4056816	total: 6.39s	remaining: 26.3s
# 127:	learn: 0.4054669	total: 6.47s	remaining: 26.4s
# 128:	learn: 0.4051164	total: 6.51s	remaining: 26.3s
# 129:	learn: 0.4049787	total: 6.56s	remaining: 26.3s
# 130:	learn: 0.4048195	total: 6.62s	remaining: 26.2s
# 131:	learn: 0.4046473	total: 6.66s	remaining: 26.1s
# 132:	learn: 0.4043027	total: 6.71s	remaining: 26.1s
# 133:	learn: 0.4041752	total: 6.75s	remaining: 26s
# 134:	learn: 0.4039929	total: 6.81s	remaining: 26s
# 135:	learn: 0.4036031	total: 6.86s	remaining: 25.9s
# 136:	learn: 0.4034617	total: 6.91s	remaining: 25.9s
# 137:	learn: 0.4033362	total: 6.96s	remaining: 25.8s
# 138:	learn: 0.4031884	total: 7s	remaining: 25.7s
# 139:	learn: 0.4030335	total: 7.05s	remaining: 25.7s
# 140:	learn: 0.4029566	total: 7.09s	remaining: 25.6s
# 141:	learn: 0.4025824	total: 7.14s	remaining: 25.5s
# 142:	learn: 0.4024418	total: 7.18s	remaining: 25.5s
# 143:	learn: 0.4016226	total: 7.24s	remaining: 25.5s
# 144:	learn: 0.4014913	total: 7.29s	remaining: 25.4s
# 145:	learn: 0.4013626	total: 7.34s	remaining: 25.3s
# 146:	learn: 0.4012541	total: 7.38s	remaining: 25.3s
# 147:	learn: 0.4010910	total: 7.43s	remaining: 25.2s
# 148:	learn: 0.4008323	total: 7.47s	remaining: 25.1s
# 149:	learn: 0.4004499	total: 7.53s	remaining: 25.1s
# 150:	learn: 0.4003117	total: 7.57s	remaining: 25s
# 151:	learn: 0.4001844	total: 7.62s	remaining: 25s
# 152:	learn: 0.3999190	total: 7.67s	remaining: 24.9s
# 153:	learn: 0.3996425	total: 7.72s	remaining: 24.9s
# 154:	learn: 0.3994905	total: 7.78s	remaining: 24.8s
# 155:	learn: 0.3993235	total: 7.83s	remaining: 24.8s
# 156:	learn: 0.3991906	total: 7.88s	remaining: 24.8s
# 157:	learn: 0.3990923	total: 7.92s	remaining: 24.7s
# 158:	learn: 0.3988451	total: 7.97s	remaining: 24.6s
# 159:	learn: 0.3986715	total: 8.03s	remaining: 24.6s
# 160:	learn: 0.3984660	total: 8.08s	remaining: 24.5s
# 161:	learn: 0.3982564	total: 8.12s	remaining: 24.5s
# 162:	learn: 0.3980123	total: 8.17s	remaining: 24.4s
# 163:	learn: 0.3978970	total: 8.22s	remaining: 24.4s
# 164:	learn: 0.3977112	total: 8.26s	remaining: 24.3s
# 165:	learn: 0.3975877	total: 8.31s	remaining: 24.2s
# 166:	learn: 0.3973795	total: 8.35s	remaining: 24.2s
# 167:	learn: 0.3972562	total: 8.41s	remaining: 24.1s
# 168:	learn: 0.3972225	total: 8.45s	remaining: 24.1s
# 169:	learn: 0.3971430	total: 8.5s	remaining: 24s
# 170:	learn: 0.3969194	total: 8.55s	remaining: 23.9s
# 171:	learn: 0.3967613	total: 8.59s	remaining: 23.9s
# 172:	learn: 0.3966711	total: 8.64s	remaining: 23.8s
# 173:	learn: 0.3966211	total: 8.68s	remaining: 23.7s
# 174:	learn: 0.3962329	total: 8.73s	remaining: 23.7s
# 175:	learn: 0.3960799	total: 8.77s	remaining: 23.6s
# 176:	learn: 0.3958323	total: 8.83s	remaining: 23.6s
# 177:	learn: 0.3955956	total: 8.88s	remaining: 23.5s
# 178:	learn: 0.3954783	total: 8.92s	remaining: 23.5s
# 179:	learn: 0.3953048	total: 8.97s	remaining: 23.4s
# 180:	learn: 0.3950458	total: 9.02s	remaining: 23.4s
# 181:	learn: 0.3947250	total: 9.07s	remaining: 23.3s
# 182:	learn: 0.3947029	total: 9.11s	remaining: 23.3s
# 183:	learn: 0.3945022	total: 9.16s	remaining: 23.2s
# 184:	learn: 0.3943948	total: 9.21s	remaining: 23.1s
# 185:	learn: 0.3942768	total: 9.25s	remaining: 23.1s
# 186:	learn: 0.3940908	total: 9.29s	remaining: 23s
# 187:	learn: 0.3939349	total: 9.33s	remaining: 22.9s
# 188:	learn: 0.3937787	total: 9.37s	remaining: 22.9s
# 189:	learn: 0.3934427	total: 9.43s	remaining: 22.8s
# 190:	learn: 0.3933235	total: 9.47s	remaining: 22.8s
# 191:	learn: 0.3930992	total: 9.52s	remaining: 22.7s
# 192:	learn: 0.3930052	total: 9.56s	remaining: 22.6s
# 193:	learn: 0.3928223	total: 9.62s	remaining: 22.6s
# 194:	learn: 0.3925332	total: 9.67s	remaining: 22.6s
# 195:	learn: 0.3924771	total: 9.71s	remaining: 22.5s
# 196:	learn: 0.3923332	total: 9.76s	remaining: 22.4s
# 197:	learn: 0.3920876	total: 9.81s	remaining: 22.4s
# 198:	learn: 0.3919922	total: 9.86s	remaining: 22.3s
# 199:	learn: 0.3918837	total: 9.9s	remaining: 22.3s
# 200:	learn: 0.3915841	total: 9.96s	remaining: 22.2s
# 201:	learn: 0.3914561	total: 10s	remaining: 22.2s
# 202:	learn: 0.3911662	total: 10s	remaining: 22.1s
# 203:	learn: 0.3910444	total: 10.1s	remaining: 22.1s
# 204:	learn: 0.3909384	total: 10.1s	remaining: 22s
# 205:	learn: 0.3908530	total: 10.2s	remaining: 21.9s
# 206:	learn: 0.3907022	total: 10.2s	remaining: 21.9s
# 207:	learn: 0.3905674	total: 10.3s	remaining: 21.9s
# 208:	learn: 0.3898809	total: 10.3s	remaining: 21.8s
# 209:	learn: 0.3896610	total: 10.4s	remaining: 21.8s
# 210:	learn: 0.3893313	total: 10.4s	remaining: 21.7s
# 211:	learn: 0.3891696	total: 10.5s	remaining: 21.7s
# 212:	learn: 0.3890751	total: 10.5s	remaining: 21.6s
# 213:	learn: 0.3889702	total: 10.6s	remaining: 21.6s
# 214:	learn: 0.3886770	total: 10.6s	remaining: 21.5s
# 215:	learn: 0.3884352	total: 10.7s	remaining: 21.5s
# 216:	learn: 0.3883265	total: 10.7s	remaining: 21.4s
# 217:	learn: 0.3882584	total: 10.8s	remaining: 21.3s
# 218:	learn: 0.3878588	total: 10.8s	remaining: 21.3s
# 219:	learn: 0.3877350	total: 10.9s	remaining: 21.3s
# 220:	learn: 0.3876408	total: 10.9s	remaining: 21.2s
# 221:	learn: 0.3875113	total: 11s	remaining: 21.2s
# 222:	learn: 0.3874911	total: 11s	remaining: 21.1s
# 223:	learn: 0.3873579	total: 11.1s	remaining: 21.1s
# 224:	learn: 0.3873278	total: 11.1s	remaining: 21s
# 225:	learn: 0.3870270	total: 11.2s	remaining: 20.9s
# 226:	learn: 0.3868657	total: 11.2s	remaining: 20.9s
# 227:	learn: 0.3867329	total: 11.3s	remaining: 20.8s
# 228:	learn: 0.3865792	total: 11.3s	remaining: 20.8s
# 229:	learn: 0.3864032	total: 11.4s	remaining: 20.7s
# 230:	learn: 0.3862227	total: 11.4s	remaining: 20.7s
# 231:	learn: 0.3859887	total: 11.5s	remaining: 20.6s
# 232:	learn: 0.3859119	total: 11.5s	remaining: 20.6s
# 233:	learn: 0.3857135	total: 11.5s	remaining: 20.5s
# 234:	learn: 0.3855648	total: 11.6s	remaining: 20.5s
# 235:	learn: 0.3854038	total: 11.7s	remaining: 20.4s
# 236:	learn: 0.3853221	total: 11.7s	remaining: 20.4s
# 237:	learn: 0.3851203	total: 11.7s	remaining: 20.3s
# 238:	learn: 0.3850044	total: 11.8s	remaining: 20.3s
# 239:	learn: 0.3846613	total: 11.9s	remaining: 20.3s
# 240:	learn: 0.3844809	total: 11.9s	remaining: 20.2s
# 241:	learn: 0.3843028	total: 11.9s	remaining: 20.1s
# 242:	learn: 0.3842349	total: 12s	remaining: 20.1s
# 243:	learn: 0.3839610	total: 12.1s	remaining: 20.1s
# 244:	learn: 0.3838257	total: 12.1s	remaining: 20s
# 245:	learn: 0.3836890	total: 12.1s	remaining: 19.9s
# 246:	learn: 0.3834792	total: 12.2s	remaining: 19.9s
# 247:	learn: 0.3823323	total: 12.3s	remaining: 19.9s
# 248:	learn: 0.3822492	total: 12.3s	remaining: 19.8s
# 249:	learn: 0.3819674	total: 12.4s	remaining: 19.8s
# 250:	learn: 0.3818309	total: 12.4s	remaining: 19.8s
# 251:	learn: 0.3816874	total: 12.5s	remaining: 19.7s
# 252:	learn: 0.3815499	total: 12.5s	remaining: 19.7s
# 253:	learn: 0.3813778	total: 12.6s	remaining: 19.6s
# 254:	learn: 0.3812522	total: 12.6s	remaining: 19.6s
# 255:	learn: 0.3811387	total: 12.7s	remaining: 19.5s
# 256:	learn: 0.3808453	total: 12.7s	remaining: 19.5s
# 257:	learn: 0.3806668	total: 12.8s	remaining: 19.4s
# 258:	learn: 0.3805691	total: 12.8s	remaining: 19.4s
# 259:	learn: 0.3803496	total: 12.9s	remaining: 19.3s
# 260:	learn: 0.3801325	total: 13s	remaining: 19.3s
# 261:	learn: 0.3799872	total: 13s	remaining: 19.3s
# 262:	learn: 0.3798806	total: 13.1s	remaining: 19.2s
# 263:	learn: 0.3796671	total: 13.1s	remaining: 19.2s
# 264:	learn: 0.3794023	total: 13.2s	remaining: 19.1s
# 265:	learn: 0.3792759	total: 13.2s	remaining: 19.1s
# 266:	learn: 0.3791258	total: 13.3s	remaining: 19.1s
# 267:	learn: 0.3789809	total: 13.3s	remaining: 19s
# 268:	learn: 0.3787759	total: 13.4s	remaining: 19s
# 269:	learn: 0.3786989	total: 13.4s	remaining: 18.9s
# 270:	learn: 0.3786103	total: 13.5s	remaining: 18.9s
# 271:	learn: 0.3784438	total: 13.5s	remaining: 18.8s
# 272:	learn: 0.3783285	total: 13.6s	remaining: 18.8s
# 273:	learn: 0.3781982	total: 13.6s	remaining: 18.7s
# 274:	learn: 0.3780851	total: 13.7s	remaining: 18.7s
# 275:	learn: 0.3778874	total: 13.7s	remaining: 18.6s
# 276:	learn: 0.3778331	total: 13.8s	remaining: 18.6s
# 277:	learn: 0.3776585	total: 13.9s	remaining: 18.5s
# 278:	learn: 0.3774682	total: 13.9s	remaining: 18.5s
# 279:	learn: 0.3773551	total: 13.9s	remaining: 18.4s
# 280:	learn: 0.3772604	total: 14s	remaining: 18.4s
# 281:	learn: 0.3771107	total: 14s	remaining: 18.3s
# 282:	learn: 0.3768351	total: 14.1s	remaining: 18.3s
# 283:	learn: 0.3765963	total: 14.2s	remaining: 18.2s
# 284:	learn: 0.3763927	total: 14.2s	remaining: 18.2s
# 285:	learn: 0.3762367	total: 14.3s	remaining: 18.1s
# 286:	learn: 0.3760398	total: 14.3s	remaining: 18.1s
# 287:	learn: 0.3757697	total: 14.3s	remaining: 18s
# 288:	learn: 0.3756515	total: 14.4s	remaining: 18s
# 289:	learn: 0.3755033	total: 14.4s	remaining: 17.9s
# 290:	learn: 0.3753643	total: 14.5s	remaining: 17.9s
# 291:	learn: 0.3752203	total: 14.5s	remaining: 17.8s
# 292:	learn: 0.3750432	total: 14.6s	remaining: 17.8s
# 293:	learn: 0.3749799	total: 14.6s	remaining: 17.7s
# 294:	learn: 0.3748991	total: 14.7s	remaining: 17.7s
# 295:	learn: 0.3747153	total: 14.7s	remaining: 17.6s
# 296:	learn: 0.3745663	total: 14.8s	remaining: 17.6s
# 297:	learn: 0.3743340	total: 14.8s	remaining: 17.5s
# 298:	learn: 0.3742018	total: 14.9s	remaining: 17.5s
# 299:	learn: 0.3741634	total: 14.9s	remaining: 17.4s
# 300:	learn: 0.3740347	total: 15s	remaining: 17.4s
# 301:	learn: 0.3739270	total: 15.1s	remaining: 17.3s
# 302:	learn: 0.3738838	total: 15.1s	remaining: 17.3s
# 303:	learn: 0.3737125	total: 15.2s	remaining: 17.3s
# 304:	learn: 0.3735870	total: 15.2s	remaining: 17.2s
# 305:	learn: 0.3734972	total: 15.3s	remaining: 17.2s
# 306:	learn: 0.3734266	total: 15.3s	remaining: 17.1s
# 307:	learn: 0.3733604	total: 15.4s	remaining: 17.1s
# 308:	learn: 0.3731884	total: 15.5s	remaining: 17.1s
# 309:	learn: 0.3730880	total: 15.5s	remaining: 17s
# 310:	learn: 0.3729039	total: 15.6s	remaining: 17s
# 311:	learn: 0.3728037	total: 15.6s	remaining: 16.9s
# 312:	learn: 0.3725149	total: 15.7s	remaining: 16.9s
# 313:	learn: 0.3723286	total: 15.7s	remaining: 16.8s
# 314:	learn: 0.3721786	total: 15.8s	remaining: 16.8s
# 315:	learn: 0.3720418	total: 15.8s	remaining: 16.7s
# 316:	learn: 0.3719474	total: 15.9s	remaining: 16.7s
# 317:	learn: 0.3717355	total: 15.9s	remaining: 16.6s
# 318:	learn: 0.3714967	total: 16s	remaining: 16.6s
# 319:	learn: 0.3713461	total: 16s	remaining: 16.5s
# 320:	learn: 0.3712851	total: 16.1s	remaining: 16.5s
# 321:	learn: 0.3711212	total: 16.1s	remaining: 16.4s
# 322:	learn: 0.3710473	total: 16.2s	remaining: 16.4s
# 323:	learn: 0.3707606	total: 16.3s	remaining: 16.4s
# 324:	learn: 0.3707275	total: 16.3s	remaining: 16.3s
# 325:	learn: 0.3705901	total: 16.3s	remaining: 16.2s
# 326:	learn: 0.3704630	total: 16.4s	remaining: 16.2s
# 327:	learn: 0.3702783	total: 16.5s	remaining: 16.2s
# 328:	learn: 0.3701214	total: 16.5s	remaining: 16.1s
# 329:	learn: 0.3700644	total: 16.5s	remaining: 16s
# 330:	learn: 0.3698462	total: 16.6s	remaining: 16s
# 331:	learn: 0.3697872	total: 16.6s	remaining: 15.9s
# 332:	learn: 0.3696019	total: 16.7s	remaining: 15.9s
# 333:	learn: 0.3694463	total: 16.7s	remaining: 15.8s
# 334:	learn: 0.3694317	total: 16.8s	remaining: 15.8s
# 335:	learn: 0.3693499	total: 16.8s	remaining: 15.7s
# 336:	learn: 0.3692268	total: 16.9s	remaining: 15.7s
# 337:	learn: 0.3690884	total: 16.9s	remaining: 15.6s
# 338:	learn: 0.3689927	total: 17s	remaining: 15.6s
# 339:	learn: 0.3689001	total: 17s	remaining: 15.5s
# 340:	learn: 0.3687944	total: 17.1s	remaining: 15.5s
# 341:	learn: 0.3686417	total: 17.1s	remaining: 15.4s
# 342:	learn: 0.3683671	total: 17.2s	remaining: 15.4s
# 343:	learn: 0.3682358	total: 17.2s	remaining: 15.3s
# 344:	learn: 0.3681037	total: 17.3s	remaining: 15.3s
# 345:	learn: 0.3678436	total: 17.3s	remaining: 15.2s
# 346:	learn: 0.3676849	total: 17.4s	remaining: 15.2s
# 347:	learn: 0.3674859	total: 17.4s	remaining: 15.1s
# 348:	learn: 0.3674180	total: 17.5s	remaining: 15.1s
# 349:	learn: 0.3673317	total: 17.5s	remaining: 15s
# 350:	learn: 0.3672646	total: 17.6s	remaining: 15s
# 351:	learn: 0.3671634	total: 17.6s	remaining: 14.9s
# 352:	learn: 0.3668148	total: 17.7s	remaining: 14.9s
# 353:	learn: 0.3666622	total: 17.7s	remaining: 14.8s
# 354:	learn: 0.3663488	total: 17.8s	remaining: 14.8s
# 355:	learn: 0.3661807	total: 17.8s	remaining: 14.7s
# 356:	learn: 0.3660249	total: 17.9s	remaining: 14.7s
# 357:	learn: 0.3658802	total: 17.9s	remaining: 14.6s
# 358:	learn: 0.3657925	total: 18s	remaining: 14.6s
# 359:	learn: 0.3656385	total: 18s	remaining: 14.5s
# 360:	learn: 0.3655611	total: 18.1s	remaining: 14.5s
# 361:	learn: 0.3654392	total: 18.1s	remaining: 14.4s
# 362:	learn: 0.3652226	total: 18.2s	remaining: 14.4s
# 363:	learn: 0.3650012	total: 18.2s	remaining: 14.3s
# 364:	learn: 0.3649648	total: 18.3s	remaining: 14.3s
# 365:	learn: 0.3647059	total: 18.3s	remaining: 14.2s
# 366:	learn: 0.3646588	total: 18.4s	remaining: 14.2s
# 367:	learn: 0.3644738	total: 18.5s	remaining: 14.1s
# 368:	learn: 0.3643752	total: 18.5s	remaining: 14.1s
# 369:	learn: 0.3643334	total: 18.5s	remaining: 14s
# 370:	learn: 0.3642568	total: 18.6s	remaining: 14s
# 371:	learn: 0.3640626	total: 18.6s	remaining: 13.9s
# 372:	learn: 0.3638758	total: 18.7s	remaining: 13.9s
# 373:	learn: 0.3638309	total: 18.7s	remaining: 13.8s
# 374:	learn: 0.3637221	total: 18.8s	remaining: 13.8s
# 375:	learn: 0.3636032	total: 18.8s	remaining: 13.7s
# 376:	learn: 0.3634978	total: 18.9s	remaining: 13.7s
# 377:	learn: 0.3633720	total: 18.9s	remaining: 13.6s
# 378:	learn: 0.3632077	total: 19s	remaining: 13.6s
# 379:	learn: 0.3630941	total: 19s	remaining: 13.5s
# 380:	learn: 0.3629151	total: 19.1s	remaining: 13.5s
# 381:	learn: 0.3628675	total: 19.1s	remaining: 13.4s
# 382:	learn: 0.3627617	total: 19.2s	remaining: 13.4s
# 383:	learn: 0.3627360	total: 19.2s	remaining: 13.3s
# 384:	learn: 0.3626784	total: 19.2s	remaining: 13.2s
# 385:	learn: 0.3625620	total: 19.3s	remaining: 13.2s
# 386:	learn: 0.3624784	total: 19.3s	remaining: 13.1s
# 387:	learn: 0.3622561	total: 19.4s	remaining: 13.1s
# 388:	learn: 0.3621755	total: 19.4s	remaining: 13s
# 389:	learn: 0.3620284	total: 19.5s	remaining: 13s
# 390:	learn: 0.3618845	total: 19.5s	remaining: 12.9s
# 391:	learn: 0.3615749	total: 19.6s	remaining: 12.9s
# 392:	learn: 0.3615013	total: 19.6s	remaining: 12.8s
# 393:	learn: 0.3613611	total: 19.7s	remaining: 12.8s
# 394:	learn: 0.3612929	total: 19.7s	remaining: 12.7s
# 395:	learn: 0.3612508	total: 19.8s	remaining: 12.7s
# 396:	learn: 0.3611867	total: 19.8s	remaining: 12.6s
# 397:	learn: 0.3611325	total: 19.9s	remaining: 12.6s
# 398:	learn: 0.3610645	total: 19.9s	remaining: 12.5s
# 399:	learn: 0.3610092	total: 19.9s	remaining: 12.5s
# 400:	learn: 0.3609411	total: 20s	remaining: 12.4s
# 401:	learn: 0.3608442	total: 20s	remaining: 12.4s
# 402:	learn: 0.3606483	total: 20.1s	remaining: 12.3s
# 403:	learn: 0.3604689	total: 20.1s	remaining: 12.3s
# 404:	learn: 0.3604485	total: 20.2s	remaining: 12.2s
# 405:	learn: 0.3603360	total: 20.2s	remaining: 12.2s
# 406:	learn: 0.3601981	total: 20.3s	remaining: 12.1s
# 407:	learn: 0.3600922	total: 20.4s	remaining: 12.1s
# 408:	learn: 0.3600347	total: 20.4s	remaining: 12s
# 409:	learn: 0.3599319	total: 20.5s	remaining: 12s
# 410:	learn: 0.3598825	total: 20.5s	remaining: 11.9s
# 411:	learn: 0.3597866	total: 20.6s	remaining: 11.9s
# 412:	learn: 0.3595678	total: 20.6s	remaining: 11.8s
# 413:	learn: 0.3593305	total: 20.7s	remaining: 11.8s
# 414:	learn: 0.3592387	total: 20.7s	remaining: 11.7s
# 415:	learn: 0.3591567	total: 20.8s	remaining: 11.7s
# 416:	learn: 0.3590924	total: 20.8s	remaining: 11.6s
# 417:	learn: 0.3590052	total: 20.9s	remaining: 11.6s
# 418:	learn: 0.3588768	total: 20.9s	remaining: 11.5s
# 419:	learn: 0.3587049	total: 21s	remaining: 11.5s
# 420:	learn: 0.3584912	total: 21s	remaining: 11.4s
# 421:	learn: 0.3583040	total: 21.1s	remaining: 11.4s
# 422:	learn: 0.3582058	total: 21.1s	remaining: 11.3s
# 423:	learn: 0.3579380	total: 21.2s	remaining: 11.3s
# 424:	learn: 0.3577921	total: 21.2s	remaining: 11.2s
# 425:	learn: 0.3575814	total: 21.3s	remaining: 11.2s
# 426:	learn: 0.3574217	total: 21.3s	remaining: 11.1s
# 427:	learn: 0.3573071	total: 21.4s	remaining: 11.1s
# 428:	learn: 0.3571266	total: 21.4s	remaining: 11s
# 429:	learn: 0.3570429	total: 21.5s	remaining: 11s
# 430:	learn: 0.3568858	total: 21.6s	remaining: 11s
# 431:	learn: 0.3568452	total: 21.6s	remaining: 10.9s
# 432:	learn: 0.3568166	total: 21.6s	remaining: 10.8s
# 433:	learn: 0.3567342	total: 21.7s	remaining: 10.8s
# 434:	learn: 0.3565715	total: 21.8s	remaining: 10.8s
# 435:	learn: 0.3563472	total: 21.8s	remaining: 10.7s
# 436:	learn: 0.3562477	total: 21.9s	remaining: 10.7s
# 437:	learn: 0.3561301	total: 21.9s	remaining: 10.6s
# 438:	learn: 0.3560833	total: 22s	remaining: 10.6s
# 439:	learn: 0.3558817	total: 22s	remaining: 10.5s
# 440:	learn: 0.3557332	total: 22.1s	remaining: 10.5s
# 441:	learn: 0.3556436	total: 22.1s	remaining: 10.4s
# 442:	learn: 0.3547718	total: 22.2s	remaining: 10.4s
# 443:	learn: 0.3546721	total: 22.3s	remaining: 10.3s
# 444:	learn: 0.3546248	total: 22.3s	remaining: 10.3s
# 445:	learn: 0.3545426	total: 22.4s	remaining: 10.2s
# 446:	learn: 0.3544737	total: 22.4s	remaining: 10.2s
# 447:	learn: 0.3543221	total: 22.5s	remaining: 10.1s
# 448:	learn: 0.3542279	total: 22.5s	remaining: 10.1s
# 449:	learn: 0.3540317	total: 22.6s	remaining: 10s
# 450:	learn: 0.3537823	total: 22.6s	remaining: 9.99s
# 451:	learn: 0.3537047	total: 22.7s	remaining: 9.94s
# 452:	learn: 0.3535685	total: 22.7s	remaining: 9.88s
# 453:	learn: 0.3533382	total: 22.8s	remaining: 9.84s
# 454:	learn: 0.3532657	total: 22.9s	remaining: 9.8s
# 455:	learn: 0.3530120	total: 23s	remaining: 9.78s
# 456:	learn: 0.3529089	total: 23s	remaining: 9.72s
# 457:	learn: 0.3527806	total: 23.1s	remaining: 9.67s
# 458:	learn: 0.3526574	total: 23.1s	remaining: 9.63s
# 459:	learn: 0.3524644	total: 23.2s	remaining: 9.58s
# 460:	learn: 0.3523002	total: 23.2s	remaining: 9.53s
# 461:	learn: 0.3522432	total: 23.3s	remaining: 9.48s
# 462:	learn: 0.3521388	total: 23.3s	remaining: 9.43s
# 463:	learn: 0.3520264	total: 23.4s	remaining: 9.37s
# 464:	learn: 0.3519751	total: 23.4s	remaining: 9.32s
# 465:	learn: 0.3519082	total: 23.5s	remaining: 9.26s
# 466:	learn: 0.3517602	total: 23.5s	remaining: 9.21s
# 467:	learn: 0.3516467	total: 23.6s	remaining: 9.17s
# 468:	learn: 0.3515277	total: 23.6s	remaining: 9.11s
# 469:	learn: 0.3513035	total: 23.7s	remaining: 9.07s
# 470:	learn: 0.3511008	total: 23.7s	remaining: 9.02s
# 471:	learn: 0.3510183	total: 23.8s	remaining: 8.97s
# 472:	learn: 0.3509491	total: 23.8s	remaining: 8.91s
# 473:	learn: 0.3508252	total: 23.9s	remaining: 8.86s
# 474:	learn: 0.3506575	total: 23.9s	remaining: 8.81s
# 475:	learn: 0.3504544	total: 24s	remaining: 8.77s
# 476:	learn: 0.3503073	total: 24s	remaining: 8.71s
# 477:	learn: 0.3501798	total: 24.1s	remaining: 8.66s
# 478:	learn: 0.3499768	total: 24.1s	remaining: 8.61s
# 479:	learn: 0.3498784	total: 24.2s	remaining: 8.56s
# 480:	learn: 0.3498055	total: 24.2s	remaining: 8.51s
# 481:	learn: 0.3496551	total: 24.3s	remaining: 8.46s
# 482:	learn: 0.3495692	total: 24.3s	remaining: 8.41s
# 483:	learn: 0.3495021	total: 24.4s	remaining: 8.36s
# 484:	learn: 0.3494147	total: 24.4s	remaining: 8.3s
# 485:	learn: 0.3493695	total: 24.5s	remaining: 8.25s
# 486:	learn: 0.3492889	total: 24.5s	remaining: 8.2s
# 487:	learn: 0.3491993	total: 24.6s	remaining: 8.15s
# 488:	learn: 0.3491287	total: 24.6s	remaining: 8.1s
# 489:	learn: 0.3489885	total: 24.6s	remaining: 8.04s
# 490:	learn: 0.3488902	total: 24.7s	remaining: 7.99s
# 491:	learn: 0.3487627	total: 24.7s	remaining: 7.94s
# 492:	learn: 0.3482639	total: 24.8s	remaining: 7.89s
# 493:	learn: 0.3481137	total: 24.8s	remaining: 7.84s
# 494:	learn: 0.3479944	total: 24.9s	remaining: 7.79s
# 495:	learn: 0.3478657	total: 24.9s	remaining: 7.75s
# 496:	learn: 0.3475890	total: 25s	remaining: 7.7s
# 497:	learn: 0.3474424	total: 25.1s	remaining: 7.66s
# 498:	learn: 0.3473326	total: 25.2s	remaining: 7.63s
# 499:	learn: 0.3473069	total: 25.3s	remaining: 7.58s
# 500:	learn: 0.3472259	total: 25.4s	remaining: 7.55s
# 501:	learn: 0.3471287	total: 25.5s	remaining: 7.51s
# 502:	learn: 0.3469599	total: 25.5s	remaining: 7.46s
# 503:	learn: 0.3467887	total: 25.6s	remaining: 7.41s
# 504:	learn: 0.3467197	total: 25.6s	remaining: 7.36s
# 505:	learn: 0.3466608	total: 25.7s	remaining: 7.31s
# 506:	learn: 0.3465698	total: 25.7s	remaining: 7.26s
# 507:	learn: 0.3464969	total: 25.8s	remaining: 7.21s
# 508:	learn: 0.3464133	total: 25.8s	remaining: 7.16s
# 509:	learn: 0.3462888	total: 25.9s	remaining: 7.11s
# 510:	learn: 0.3461358	total: 26s	remaining: 7.07s
# 511:	learn: 0.3460736	total: 26s	remaining: 7.02s
# 512:	learn: 0.3458552	total: 26.1s	remaining: 6.98s
# 513:	learn: 0.3457536	total: 26.2s	remaining: 6.93s
# 514:	learn: 0.3456489	total: 26.2s	remaining: 6.88s
# 515:	learn: 0.3454350	total: 26.3s	remaining: 6.83s
# 516:	learn: 0.3452966	total: 26.3s	remaining: 6.78s
# 517:	learn: 0.3452027	total: 26.4s	remaining: 6.73s
# 518:	learn: 0.3450011	total: 26.4s	remaining: 6.68s
# 519:	learn: 0.3449176	total: 26.5s	remaining: 6.63s
# 520:	learn: 0.3447763	total: 26.6s	remaining: 6.58s
# 521:	learn: 0.3446458	total: 26.6s	remaining: 6.52s
# 522:	learn: 0.3444755	total: 26.7s	remaining: 6.47s
# 523:	learn: 0.3443283	total: 26.7s	remaining: 6.42s
# 524:	learn: 0.3442239	total: 26.8s	remaining: 6.37s
# 525:	learn: 0.3441138	total: 26.8s	remaining: 6.32s
# 526:	learn: 0.3439117	total: 26.9s	remaining: 6.27s
# 527:	learn: 0.3438374	total: 26.9s	remaining: 6.22s
# 528:	learn: 0.3437742	total: 27s	remaining: 6.17s
# 529:	learn: 0.3437294	total: 27s	remaining: 6.12s
# 530:	learn: 0.3436442	total: 27.1s	remaining: 6.06s
# 531:	learn: 0.3435579	total: 27.1s	remaining: 6.01s
# 532:	learn: 0.3434107	total: 27.2s	remaining: 5.96s
# 533:	learn: 0.3433631	total: 27.2s	remaining: 5.91s
# 534:	learn: 0.3432970	total: 27.3s	remaining: 5.86s
# 535:	learn: 0.3432175	total: 27.3s	remaining: 5.81s
# 536:	learn: 0.3430324	total: 27.4s	remaining: 5.76s
# 537:	learn: 0.3429145	total: 27.4s	remaining: 5.71s
# 538:	learn: 0.3428845	total: 27.4s	remaining: 5.65s
# 539:	learn: 0.3427416	total: 27.5s	remaining: 5.6s
# 540:	learn: 0.3426807	total: 27.5s	remaining: 5.55s
# 541:	learn: 0.3425942	total: 27.6s	remaining: 5.5s
# 542:	learn: 0.3424456	total: 27.6s	remaining: 5.45s
# 543:	learn: 0.3422979	total: 27.7s	remaining: 5.4s
# 544:	learn: 0.3420814	total: 27.8s	remaining: 5.35s
# 545:	learn: 0.3420201	total: 27.8s	remaining: 5.29s
# 546:	learn: 0.3419812	total: 27.8s	remaining: 5.24s
# 547:	learn: 0.3418435	total: 27.9s	remaining: 5.19s
# 548:	learn: 0.3416895	total: 28s	remaining: 5.14s
# 549:	learn: 0.3415482	total: 28s	remaining: 5.09s
# 550:	learn: 0.3414904	total: 28.1s	remaining: 5.04s
# 551:	learn: 0.3413949	total: 28.1s	remaining: 4.99s
# 552:	learn: 0.3413265	total: 28.2s	remaining: 4.94s
# 553:	learn: 0.3412472	total: 28.2s	remaining: 4.89s
# 554:	learn: 0.3411461	total: 28.3s	remaining: 4.84s
# 555:	learn: 0.3410236	total: 28.3s	remaining: 4.79s
# 556:	learn: 0.3409098	total: 28.4s	remaining: 4.74s
# 557:	learn: 0.3408143	total: 28.4s	remaining: 4.69s
# 558:	learn: 0.3405858	total: 28.5s	remaining: 4.63s
# 559:	learn: 0.3404839	total: 28.5s	remaining: 4.58s
# 560:	learn: 0.3403680	total: 28.6s	remaining: 4.53s
# 561:	learn: 0.3403115	total: 28.6s	remaining: 4.48s
# 562:	learn: 0.3401647	total: 28.7s	remaining: 4.43s
# 563:	learn: 0.3399123	total: 28.7s	remaining: 4.38s
# 564:	learn: 0.3398278	total: 28.8s	remaining: 4.33s
# 565:	learn: 0.3397569	total: 28.9s	remaining: 4.28s
# 566:	learn: 0.3395970	total: 28.9s	remaining: 4.23s
# 567:	learn: 0.3395096	total: 29s	remaining: 4.18s
# 568:	learn: 0.3394540	total: 29s	remaining: 4.13s
# 569:	learn: 0.3392025	total: 29.1s	remaining: 4.08s
# 570:	learn: 0.3389954	total: 29.1s	remaining: 4.03s
# 571:	learn: 0.3388487	total: 29.2s	remaining: 3.98s
# 572:	learn: 0.3387550	total: 29.2s	remaining: 3.93s
# 573:	learn: 0.3386153	total: 29.3s	remaining: 3.88s
# 574:	learn: 0.3385161	total: 29.3s	remaining: 3.83s
# 575:	learn: 0.3384224	total: 29.4s	remaining: 3.77s
# 576:	learn: 0.3383232	total: 29.4s	remaining: 3.72s
# 577:	learn: 0.3382116	total: 29.5s	remaining: 3.67s
# 578:	learn: 0.3381657	total: 29.5s	remaining: 3.62s
# 579:	learn: 0.3381023	total: 29.6s	remaining: 3.57s
# 580:	learn: 0.3380407	total: 29.6s	remaining: 3.52s
# 581:	learn: 0.3380136	total: 29.7s	remaining: 3.47s
# 582:	learn: 0.3379313	total: 29.7s	remaining: 3.42s
# 583:	learn: 0.3378023	total: 29.8s	remaining: 3.37s
# 584:	learn: 0.3376968	total: 29.8s	remaining: 3.31s
# 585:	learn: 0.3376045	total: 29.9s	remaining: 3.27s
# 586:	learn: 0.3375140	total: 29.9s	remaining: 3.21s
# 587:	learn: 0.3373920	total: 30s	remaining: 3.17s
# 588:	learn: 0.3372943	total: 30.1s	remaining: 3.12s
# 589:	learn: 0.3370701	total: 30.1s	remaining: 3.06s
# 590:	learn: 0.3369062	total: 30.2s	remaining: 3.02s
# 591:	learn: 0.3368010	total: 30.3s	remaining: 2.97s
# 592:	learn: 0.3367082	total: 30.3s	remaining: 2.92s
# 593:	learn: 0.3366281	total: 30.4s	remaining: 2.87s
# 594:	learn: 0.3365471	total: 30.4s	remaining: 2.81s
# 595:	learn: 0.3364165	total: 30.5s	remaining: 2.76s
# 596:	learn: 0.3363682	total: 30.5s	remaining: 2.71s
# 597:	learn: 0.3362672	total: 30.6s	remaining: 2.66s
# 598:	learn: 0.3361594	total: 30.6s	remaining: 2.61s
# 599:	learn: 0.3360673	total: 30.7s	remaining: 2.56s
# 600:	learn: 0.3360026	total: 30.8s	remaining: 2.51s
# 601:	learn: 0.3359007	total: 30.8s	remaining: 2.46s
# 602:	learn: 0.3358168	total: 30.9s	remaining: 2.4s
# 603:	learn: 0.3357512	total: 30.9s	remaining: 2.35s
# 604:	learn: 0.3356732	total: 31s	remaining: 2.3s
# 605:	learn: 0.3355917	total: 31s	remaining: 2.25s
# 606:	learn: 0.3355060	total: 31.1s	remaining: 2.2s
# 607:	learn: 0.3354796	total: 31.1s	remaining: 2.15s
# 608:	learn: 0.3353999	total: 31.2s	remaining: 2.1s
# 609:	learn: 0.3353450	total: 31.2s	remaining: 2.05s
# 610:	learn: 0.3352515	total: 31.3s	remaining: 2s
# 611:	learn: 0.3351741	total: 31.3s	remaining: 1.94s
# 612:	learn: 0.3350973	total: 31.4s	remaining: 1.89s
# 613:	learn: 0.3349101	total: 31.4s	remaining: 1.84s
# 614:	learn: 0.3348441	total: 31.5s	remaining: 1.79s
# 615:	learn: 0.3347257	total: 31.5s	remaining: 1.74s
# 616:	learn: 0.3345737	total: 31.6s	remaining: 1.69s
# 617:	learn: 0.3343029	total: 31.6s	remaining: 1.64s
# 618:	learn: 0.3341831	total: 31.7s	remaining: 1.59s
# 619:	learn: 0.3340633	total: 31.8s	remaining: 1.54s
# 620:	learn: 0.3339399	total: 31.9s	remaining: 1.49s
# 621:	learn: 0.3338102	total: 31.9s	remaining: 1.44s
# 622:	learn: 0.3336443	total: 32.1s	remaining: 1.39s
# 623:	learn: 0.3335575	total: 32.2s	remaining: 1.34s
# 624:	learn: 0.3334220	total: 32.3s	remaining: 1.29s
# 625:	learn: 0.3333206	total: 32.3s	remaining: 1.24s
# 626:	learn: 0.3331934	total: 32.4s	remaining: 1.19s
# 627:	learn: 0.3331078	total: 32.5s	remaining: 1.14s
# 628:	learn: 0.3329659	total: 32.5s	remaining: 1.09s
# 629:	learn: 0.3328607	total: 32.6s	remaining: 1.03s
# 630:	learn: 0.3327987	total: 32.7s	remaining: 985ms
# 631:	learn: 0.3327307	total: 32.8s	remaining: 934ms
# 632:	learn: 0.3326786	total: 32.9s	remaining: 883ms
# 633:	learn: 0.3325730	total: 33s	remaining: 832ms
# 634:	learn: 0.3324623	total: 33.1s	remaining: 781ms
# 635:	learn: 0.3323251	total: 33.2s	remaining: 730ms
# 636:	learn: 0.3322584	total: 33.2s	remaining: 679ms
# 637:	learn: 0.3321758	total: 33.3s	remaining: 627ms
# 638:	learn: 0.3319593	total: 33.4s	remaining: 575ms
# 639:	learn: 0.3318230	total: 33.4s	remaining: 523ms
# 640:	learn: 0.3316563	total: 33.5s	remaining: 470ms
# 641:	learn: 0.3315854	total: 33.6s	remaining: 418ms
# 642:	learn: 0.3315399	total: 33.6s	remaining: 366ms
# 643:	learn: 0.3314692	total: 33.7s	remaining: 314ms
# 644:	learn: 0.3311451	total: 33.8s	remaining: 262ms
# 645:	learn: 0.3310946	total: 33.8s	remaining: 210ms
# 646:	learn: 0.3309668	total: 33.9s	remaining: 157ms
# 647:	learn: 0.3308980	total: 34s	remaining: 105ms
# 648:	learn: 0.3308556	total: 34.1s	remaining: 52.5ms
# 649:	learn: 0.3307559	total: 34.1s	remaining: 0us
# RandomizedSearchCV(cv=3,
#                    estimator=<catboost.core.CatBoostClassifier object at 0x7f747d4ccb20>,
#                    n_jobs=5,
#                    param_distributions={'depth': [4, 5, 6],
#                                         'iterations': [650, 700, 750],
#                                         'learning_rate': [0.5, 0.6, 0.7]},
#                    verbose=2)

# %%
CBC_predict = CBC.predict(test_data)
CBC_predict = y_encode.inverse_transform(CBC_predict)
CBC_predict = pd.DataFrame(CBC_predict, columns=["Top-up Month"], index=ID)
CBC_predict.to_csv("basic_ctbc_predictions.csv")

# %%
predict = CBC.predict(train_data)
print(f1_score(y_train, predict, average="macro"))
# Out:
# 0.6121477883375656

# %% [markdown]
# #### Light GBM

# %%
#import lightgbm as lgb

#d_train = lgb.Dataset(train_data, label=y_train)
#params = {}
#params['learning_rate'] = 0.1
#params['boosting_type'] = 'dart'
#params['objective'] = 'multiclass'
#params['metric'] = 'multi_logloss'
#params['max_depth']=7
#params['num_class'] = 7
#params['lambda'] = 0.3
#params['min_data_in_leaf'] = 25
#clf = lgb.train(params, d_train, 800)
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012757 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4975
# [LightGBM] [Info] Number of data points in the train set: 128655, number of used features: 102
# [LightGBM] [Info] Start training from score -2.732959
# [LightGBM] [Info] Start training from score -4.823700
# [LightGBM] [Info] Start training from score -3.995089
# [LightGBM] [Info] Start training from score -3.606660
# [LightGBM] [Info] Start training from score -3.738066
# [LightGBM] [Info] Start training from score -3.560765
# [LightGBM] [Info] Start training from score -0.187329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
#lgbm_predict = clf.predict(test_data)
#lgbm_predict = np.argmax(lgbm_predict,axis=1)
#lgbm_predict = y_encode.inverse_transform(lgbm_predict)
#lgbm_predict = pd.DataFrame(lgbm_predict, columns=["Top-up Month"], index=ID)
#lgbm_predict.to_csv("basic_lgbm_predictions.csv")

# %%
#predict = clf.predict(train_data)
#lgbm_predict = np.argmax(predict,axis=1)

#print(f1_score(y_train, lgbm_predict, average="macro"))
# Out:
# 0.7346033018539019
